# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as api
import threading

# %%
load_dotenv()
# Out:
# True

# %%
import alpaca_trade_api as tradeapi

# authentication and connection details
api_key = 'PKD9YJ9WLOQXHD3CXA0B'
api_secret = 'EdldrL0Iva81tFaoVaRLGWSQo6eFF518s0mx4MDt'
base_url = 'https://paper-api.alpaca.markets'

# instantiate REST API
api = tradeapi.REST(api_key, api_secret, base_url, api_version='v2')

# obtain account information
account = api.get_account()
print(account)
# Out:
# Account({   'account_blocked': False,
#     'account_number': 'PA3TWSV18ZIZ',
#     'buying_power': '398553.43',
#     'cash': '98626.16',
#     'created_at': '2021-05-07T03:02:04.234667Z',
#     'currency': 'USD',
#     'daytrade_count': 6,
#     'daytrading_buying_power': '398553.43',
#     'equity': '100078.68',
#     'id': '4da81bfd-e607-4f9f-b7b6-fb9b5cb811b6',
#     'initial_margin': '726.26',
#     'last_equity': '100000',
#     'last_maintenance_margin': '0',
#     'long_market_value': '1452.52',
#     'maintenance_margin': '435.756',
#     'multiplier': '4',
#     'pattern_day_trader': True,
#     'portfolio_value': '100078.68',
#     'regt_buying_power': '198704.84',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '100000',
#     'status': 'ACTIVE',
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False})

# %%
api.submit_order(symbol='TSLA', 
		qty=1, 
		side='buy', 
		time_in_force='gtc', 
		type='market',  
		client_order_id='0012')
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#     'canceled_at': None,
#     'client_order_id': '0012',
#     'created_at': '2021-07-30T01:58:08.865382Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '955753a2-f1e4-4b64-bc83-2ceb706ea32e',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-07-30T01:58:08.857068Z',
#     'symbol': 'TSLA',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-07-30T01:58:08.865382Z'})

# %%
symbol = 'ANY'
symbol_bars = api.get_barset(symbol, 'minute', 1).df.iloc[0]
symbol_price = symbol_bars[symbol]['close']

# %%
api.submit_order(
    symbol='ANY',
    qty=1,
    side='buy',
    type='market',
    time_in_force='gtc',
    order_class='bracket',
    stop_loss={'stop_price': symbol_price * 0.90,
               'limit_price':  symbol_price * 0.94},
    take_profit={'limit_price': symbol_price * 1.05})
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': 'b6c2f8de-65aa-46dd-95b8-2c021cc8b18d',
#     'canceled_at': None,
#     'client_order_id': '440313d7-0356-417f-bbd3-7485f7401d22',
#     'created_at': '2021-07-30T15:21:13.713223Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '1621b0b8-e447-405c-b285-a0f9f0b586cf',
#     'legs': [   {   'asset_class': 'us_equity',
#                     'asset_id': 'b6c2f8de-65aa-46dd-95b8-2c021cc8b18d',
#                     'canceled_at': None,
#                     'client_order_id': '866c6e90-f523-4c6d-9d70-19e13bbdc85b',
#                     'created_at': '2021-07-30T15:21:13.713223Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': '8051e265-e314-439a-9af0-ff810275a8d8',
#                     'legs': None,
#                     'limit_price': '3.2445',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'limit',
#                     'qty': '1',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': None,
#                     'submitted_at': '2021-07-30T15:21:13.705429Z',
#                     'symbol': 'ANY',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'limit',
#                     'updated_at': '2021-07-30T15:21:13.713223Z'},
#                 {   'asset_class': 'us_equity',
#                     'asset_id': 'b6c2f8de-65aa-46dd-95b8-2c021cc8b18d',
#                     'canceled_at': None,
#                     'client_order_id': '85d11068-8625-402f-9212-0a6872569d3d',
#                     'created_at': '2021-07-30T15:21:13.713223Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': '8750d12e-dfed-4c61-b7d8-4740cd7d081c',
#                     'legs': None,
#                     'limit_price': '2.9046',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'stop_limit',
#                     'qty': '1',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': '2.9354999999999998',
#                     'submitted_at': '2021-07-30T15:21:13.705429Z',
#                     'symbol': 'ANY',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'stop_limit',
#                     'updated_at': '2021-07-30T15:21:13.713223Z'}],
#     'limit_price': None,
#     'notional': None,
#     'order_class': 'bracket',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-07-30T15:21:13.705429Z',
#     'symbol': 'ANY',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-07-30T15:21:13.720764Z'})

# %%
symbol = 'AHPI'
symbol_bars = api.get_barset(symbol, 'minute', 1).df.iloc[0]
symbol_price = symbol_bars[symbol]['close']

# %%
api.submit_order(
    symbol='AHPI',
    qty=1,
    side='buy',
    type='market',
    time_in_force='gtc',
    order_class='bracket',
    stop_loss={'stop_price': symbol_price * 0.90,
               'limit_price':  symbol_price * 0.89},
    take_profit={'limit_price': symbol_price * 1.05})
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#     'canceled_at': None,
#     'client_order_id': '109a3007-08f6-4e37-9f60-c25287a4caf8',
#     'created_at': '2021-07-30T15:25:33.183568Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '66834a71-1944-4973-b9ac-48d583191779',
#     'legs': [   {   'asset_class': 'us_equity',
#                     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#                     'canceled_at': None,
#                     'client_order_id': '465cd2c3-b41b-4e72-ba31-d6fac5e60bc3',
#                     'created_at': '2021-07-30T15:25:33.183568Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': '2c7f70da-e545-4ae4-abfd-cd8362f4c4f5',
#                     'legs': None,
#                     'limit_price': '9.156',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'limit',
#                     'qty': '1',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': None,
#                     'submitted_at': '2021-07-30T15:25:33.175271Z',
#                     'symbol': 'AHPI',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'limit',
#                     'updated_at': '2021-07-30T15:25:33.183568Z'},
#                 {   'asset_class': 'us_equity',
#                     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#                     'canceled_at': None,
#                     'client_order_id': 'efb593fd-1872-4336-bcc5-01bc58f6aa36',
#                     'created_at': '2021-07-30T15:25:33.183568Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': '10b7003d-152e-4e43-8d6f-510e9d693598',
#                     'legs': None,
#                     'limit_price': '7.760800000000001',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'stop_limit',
#                     'qty': '1',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': '7.848000000000001',
#                     'submitted_at': '2021-07-30T15:25:33.175271Z',
#                     'symbol': 'AHPI',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'stop_limit',
#                     'updated_at': '2021-07-30T15:25:33.183568Z'}],
#     'limit_price': None,
#     'notional': None,
#     'order_class': 'bracket',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-07-30T15:25:33.175271Z',
#     'symbol': 'AHPI',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-07-30T15:25:33.191503Z'})

# %%
symbol = 'UP'
symbol_bars = api.get_barset(symbol, 'minute', 1).df.iloc[0]
symbol_price = symbol_bars[symbol]['close']

# %%
api.submit_order(
    symbol='UP',
    qty=100,
    side='buy',
    type='market',
    time_in_force='gtc',
    order_class='bracket',
    stop_loss={'stop_price': symbol_price * 0.90,
               'limit_price':  symbol_price * 0.89},
    take_profit={'limit_price': symbol_price * 1.05})
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': 'dcd3a716-87bd-42d3-bc50-f8ba438abce5',
#     'canceled_at': None,
#     'client_order_id': '93a12c08-b03a-473a-b15e-cb09b117646b',
#     'created_at': '2021-07-30T15:39:01.507884Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '94fcb11c-700c-4279-9365-fd7a17372fd7',
#     'legs': [   {   'asset_class': 'us_equity',
#                     'asset_id': 'dcd3a716-87bd-42d3-bc50-f8ba438abce5',
#                     'canceled_at': None,
#                     'client_order_id': '75e1c311-d41a-41bc-a6e0-2fd1a5c2c95f',
#                     'created_at': '2021-07-30T15:39:01.507884Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': 'e1c55ace-b6a8-43b6-9e7a-1689f92c51ca',
#                     'legs': None,
#                     'limit_price': '7.780500000000001',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'limit',
#                     'qty': '100',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': None,
#                     'submitted_at': '2021-07-30T15:39:01.500108Z',
#                     'symbol': 'UP',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'limit',
#                     'updated_at': '2021-07-30T15:39:01.507884Z'},
#                 {   'asset_class': 'us_equity',
#                     'asset_id': 'dcd3a716-87bd-42d3-bc50-f8ba438abce5',
#                     'canceled_at': None,
#                     'client_order_id': '5573db00-1546-443c-aa39-23abf547167c',
#                     'created_at': '2021-07-30T15:39:01.507884Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': 'a1a9bd13-1639-44a5-9686-f824442e8caa',
#                     'legs': None,
#                     'limit_price': '6.5949',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'stop_limit',
#                     'qty': '100',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': '6.6690000000000005',
#                     'submitted_at': '2021-07-30T15:39:01.500108Z',
#                     'symbol': 'UP',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'stop_limit',
#                     'updated_at': '2021-07-30T15:39:01.507884Z'}],
#     'limit_price': None,
#     'notional': None,
#     'order_class': 'bracket',
#     'order_type': 'market',
#     'qty': '100',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-07-30T15:39:01.500108Z',
#     'symbol': 'UP',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-07-30T15:39:01.517836Z'})

# %%
symbol = 'AHPI'
symbol_bars = api.get_barset(symbol, 'minute', 1).df.iloc[0]
symbol_price = symbol_bars[symbol]['close']

# %%
api.submit_order(
    symbol='AHPI',
    qty=100,
    side='buy',
    type='market',
    time_in_force='gtc',
    order_class='bracket',
    stop_loss={'stop_price': symbol_price * 0.90,
               'limit_price':  symbol_price * 0.89},
    take_profit={'limit_price': symbol_price * 1.05})
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#     'canceled_at': None,
#     'client_order_id': '4450fda3-1aca-496c-aa39-0ba38a43fcad',
#     'created_at': '2021-07-30T15:52:10.572313Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'b8cad713-9f76-4485-9116-3228994f7c9f',
#     'legs': [   {   'asset_class': 'us_equity',
#                     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#                     'canceled_at': None,
#                     'client_order_id': 'd5e363f7-38ea-45f7-a2c2-dbcde763d103',
#                     'created_at': '2021-07-30T15:52:10.572313Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': '344e54d8-c216-4111-8a48-752f95de0a6e',
#                     'legs': None,
#                     'limit_price': '9.7545',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'limit',
#                     'qty': '100',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': None,
#                     'submitted_at': '2021-07-30T15:52:10.563756Z',
#                     'symbol': 'AHPI',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'limit',
#                     'updated_at': '2021-07-30T15:52:10.572313Z'},
#                 {   'asset_class': 'us_equity',
#                     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#                     'canceled_at': None,
#                     'client_order_id': 'cf61dfb3-7661-4264-b233-533d15d5e7b9',
#                     'created_at': '2021-07-30T15:52:10.572313Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': 'b3d2cb9b-e0ce-478e-a6ec-e905f1009ed6',
#                     'legs': None,
#                     'limit_price': '8.268099999999999',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'stop_limit',
#                     'qty': '100',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': '8.360999999999999',
#                     'submitted_at': '2021-07-30T15:52:10.563756Z',
#                     'symbol': 'AHPI',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'stop_limit',
#                     'updated_at': '2021-07-30T15:52:10.572313Z'}],
#     'limit_price': None,
#     'notional': None,
#     'order_class': 'bracket',
#     'order_type': 'market',
#     'qty': '100',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-07-30T15:52:10.563756Z',
#     'symbol': 'AHPI',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-07-30T15:52:10.579456Z'})

# %%
symbol = 'TSLA'
symbol_bars = api.get_barset(symbol, 'minute', 1).df.iloc[0]
symbol_price = symbol_bars[symbol]['close']

# %%
api.submit_order(
    symbol='TSLA',
    qty=1,
    side='buy',
    type='market',
    time_in_force='gtc',
    order_class='bracket',
    stop_loss={'stop_price': symbol_price * 0.90,
               'limit_price':  symbol_price * 0.89},
    take_profit={'limit_price': symbol_price * 1.05})
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#     'canceled_at': None,
#     'client_order_id': '642df69d-98c4-4faf-9760-062140da218a',
#     'created_at': '2021-07-30T15:53:58.887344Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'fdddb8a5-e194-43cf-b503-635754650f41',
#     'legs': [   {   'asset_class': 'us_equity',
#                     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#                     'canceled_at': None,
#                     'client_order_id': '9c1b209a-dbff-47f3-b196-f099877e883b',
#                     'created_at': '2021-07-30T15:53:58.887344Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': 'a2e77d95-e970-4ada-8f04-02fa342b29d0',
#                     'legs': None,
#                     'limit_price': '725.9805',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'limit',
#                     'qty': '1',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': None,
#                     'submitted_at': '2021-07-30T15:53:58.8785Z',
#                     'symbol': 'TSLA',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'limit',
#                     'updated_at': '2021-07-30T15:53:58.887344Z'},
#                 {   'asset_class': 'us_equity',
#                     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#                     'canceled_at': None,
#                     'client_order_id': '694fa513-9c4a-474c-8969-2d0e0fd0f8f3',
#                     'created_at': '2021-07-30T15:53:58.887344Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': 'e833bcd1-5598-48fa-bd2a-a99f5239bfb2',
#                     'legs': None,
#                     'limit_price': '615.3548999999999',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'stop_limit',
#                     'qty': '1',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': '622.269',
#                     'submitted_at': '2021-07-30T15:53:58.8785Z',
#                     'symbol': 'TSLA',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'stop_limit',
#                     'updated_at': '2021-07-30T15:53:58.887344Z'}],
#     'limit_price': None,
#     'notional': None,
#     'order_class': 'bracket',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-07-30T15:53:58.8785Z',
#     'symbol': 'TSLA',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-07-30T15:53:58.900786Z'})

# %%
api.submit_order(
    symbol='TSLA',
    qty=1,
    side='buy',
    type='market',
    time_in_force='gtc',
    order_class='bracket',
    stop_loss={'stop_price': symbol_price * 0.90,
               'limit_price':  symbol_price * 0.89},
    take_profit={'limit_price': symbol_price * 1.05})
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#     'canceled_at': None,
#     'client_order_id': 'bf9bee7c-c351-47f2-983d-6bc9474e9ce2',
#     'created_at': '2021-07-30T16:03:55.427897Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'e125ba57-6933-4912-b202-330ca409d908',
#     'legs': [   {   'asset_class': 'us_equity',
#                     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#                     'canceled_at': None,
#                     'client_order_id': '5fb5f82e-b41e-4384-bf74-69a2e62bd910',
#                     'created_at': '2021-07-30T16:03:55.427897Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': '7d238a71-d0da-4798-bbe4-4db956fddbf7',
#                     'legs': None,
#                     'limit_price': '725.9805',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'limit',
#                     'qty': '1',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': None,
#                     'submitted_at': '2021-07-30T16:03:55.419366Z',
#                     'symbol': 'TSLA',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'limit',
#                     'updated_at': '2021-07-30T16:03:55.427897Z'},
#                 {   'asset_class': 'us_equity',
#                     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#                     'canceled_at': None,
#                     'client_order_id': 'b6180df4-adf6-46ff-9d97-5098378f2cd2',
#                     'created_at': '2021-07-30T16:03:55.427897Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': 'bb1b6ceb-6059-4af6-a325-69173a4a209a',
#                     'legs': None,
#                     'limit_price': '615.3548999999999',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'stop_limit',
#                     'qty': '1',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': '622.269',
#                     'submitted_at': '2021-07-30T16:03:55.419366Z',
#                     'symbol': 'TSLA',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'stop_limit',
#                     'updated_at': '2021-07-30T16:03:55.427897Z'}],
#     'limit_price': None,
#     'notional': None,
#     'order_class': 'bracket',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-07-30T16:03:55.419366Z',
#     'symbol': 'TSLA',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-07-30T16:03:55.435587Z'})

# %%
symbol = 'AHPI'
symbol_bars = api.get_barset(symbol, 'minute', 1).df.iloc[0]
symbol_price = symbol_bars[symbol]['close']

# %%
api.submit_order(
    symbol='AHPI',
    qty=100,
    side='buy',
    type='market',
    time_in_force='gtc',
    order_class='bracket',
    stop_loss={'stop_price': symbol_price * 0.90,
               'limit_price':  symbol_price * 0.89},
    take_profit={'limit_price': symbol_price * 1.05})
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#     'canceled_at': None,
#     'client_order_id': 'd30b3f5c-ee19-4ece-bc81-fdff23d5db28',
#     'created_at': '2021-07-30T16:38:02.449993Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': '69c7356e-41d6-41fc-a2a6-2cdfc27e78cc',
#     'legs': [   {   'asset_class': 'us_equity',
#                     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#                     'canceled_at': None,
#                     'client_order_id': 'c716015f-d429-48bc-b3de-4cc70da55c4e',
#                     'created_at': '2021-07-30T16:38:02.449993Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': '639c342a-0da8-4db3-9051-07ef1c677cf1',
#                     'legs': None,
#                     'limit_price': '9.450000000000001',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'limit',
#                     'qty': '100',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': None,
#                     'submitted_at': '2021-07-30T16:38:02.439536Z',
#                     'symbol': 'AHPI',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'limit',
#                     'updated_at': '2021-07-30T16:38:02.449993Z'},
#                 {   'asset_class': 'us_equity',
#                     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#                     'canceled_at': None,
#                     'client_order_id': '9b21f1bf-5464-4f1f-9c46-91fddb456910',
#                     'created_at': '2021-07-30T16:38:02.449993Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': 'ad2804ab-1cbd-432d-8b3f-e3a0c7220325',
#                     'legs': None,
#                     'limit_price': '8.01',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'stop_limit',
#                     'qty': '100',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': '8.1',
#                     'submitted_at': '2021-07-30T16:38:02.439536Z',
#                     'symbol': 'AHPI',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'stop_limit',
#                     'updated_at': '2021-07-30T16:38:02.449993Z'}],
#     'limit_price': None,
#     'notional': None,
#     'order_class': 'bracket',
#     'order_type': 'market',
#     'qty': '100',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-07-30T16:38:02.439536Z',
#     'symbol': 'AHPI',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-07-30T16:38:02.470918Z'})

# %%
api.submit_order(
    symbol='AHPI',
    qty=100,
    side='buy',
    type='market',
    time_in_force='gtc',
    order_class='bracket',
    stop_loss={'stop_price': symbol_price * 0.90,
               'limit_price':  symbol_price * 0.89},
    take_profit={'limit_price': symbol_price * 1.15})
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#     'canceled_at': None,
#     'client_order_id': '75e50a9b-f99b-4035-ab75-17c9a88cb6dc',
#     'created_at': '2021-07-30T17:54:27.263353Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'd8f2d376-9e59-4af4-981a-7c1d44e14938',
#     'legs': [   {   'asset_class': 'us_equity',
#                     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#                     'canceled_at': None,
#                     'client_order_id': '69fe756f-cb3e-4ada-ad0e-3e8d9382e094',
#                     'created_at': '2021-07-30T17:54:27.263353Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': '86e5fd0d-6a35-46e1-8cce-53677345ef05',
#                     'legs': None,
#                     'limit_price': '10.35',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'limit',
#                     'qty': '100',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': None,
#                     'submitted_at': '2021-07-30T17:54:27.253067Z',
#                     'symbol': 'AHPI',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'limit',
#                     'updated_at': '2021-07-30T17:54:27.263353Z'},
#                 {   'asset_class': 'us_equity',
#                     'asset_id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#                     'canceled_at': None,
#                     'client_order_id': 'ea6f9c75-4c7e-4193-b33e-4508e261787f',
#                     'created_at': '2021-07-30T17:54:27.263353Z',
#                     'expired_at': None,
#                     'extended_hours': False,
#                     'failed_at': None,
#                     'filled_at': None,
#                     'filled_avg_price': None,
#                     'filled_qty': '0',
#                     'hwm': None,
#                     'id': 'f60007a7-329c-44c6-9734-5415cd666a09',
#                     'legs': None,
#                     'limit_price': '8.01',
#                     'notional': None,
#                     'order_class': 'bracket',
#                     'order_type': 'stop_limit',
#                     'qty': '100',
#                     'replaced_at': None,
#                     'replaced_by': None,
#                     'replaces': None,
#                     'side': 'sell',
#                     'status': 'held',
#                     'stop_price': '8.1',
#                     'submitted_at': '2021-07-30T17:54:27.253067Z',
#                     'symbol': 'AHPI',
#                     'time_in_force': 'gtc',
#                     'trail_percent': None,
#                     'trail_price': None,
#                     'type': 'stop_limit',
#                     'updated_at': '2021-07-30T17:54:27.263353Z'}],
#     'limit_price': None,
#     'notional': None,
#     'order_class': 'bracket',
#     'order_type': 'market',
#     'qty': '100',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2021-07-30T17:54:27.253067Z',
#     'symbol': 'AHPI',
#     'time_in_force': 'gtc',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2021-07-30T17:54:27.271023Z'})

# %%
def time_to_market_close():
	clock = api.get_clock()
	return (clock.next_close - clock.timestamp).total_seconds()

# %%
def wait_for_market_open():
	clock = api.get_clock()
	if not clock.is_open:
		time_to_open = (clock.next_open - clock.timestamp).total_seconds()
		sleep(round(time_to_open))

# %%
# Check if the market is open now.
clock = api.get_clock()
print('The market is {}'.format('open.' if clock.is_open else 'closed.'))

# Check when the market was open on Dec. 1, 2018
date = '2021-07-29'
calendar = api.get_calendar(start=date, end=date)[0]
print('The market opened at {} and closed at {} on {}.'.format(
    calendar.open,
    calendar.close,
    date
))
# Out:
# The market is closed.
# The market opened at 09:30:00 and closed at 16:00:00 on 2021-07-29.

# %%
def send_order(direction, bar):
	if time_to_market_close() > 120:
		print(f'sent {direction} trade')
		range_size = trade_params['high'] - trade_params['low']

		if direction == 'buy':
			sl = bar.high - range_size
			tp = bar.high + range_size
		elif direction == 'sell':
			sl = bar.low + range_size
			tp = bar.low - range_size

			api.submit_order(
			symbol='AAPL',
			qty=100,
			side=direction,
			type='market',
			time_in_force='day',
			order_class='bracket',
			stop_loss=dict(stop_price=str(sl)),
			take_profit=dict(limit_price=str(tp)),
		)

return True

	wait_for_market_open()
	return False
